# %%
using Pkg
Pkg.activate("NB02")
Pkg.resolve();

# %%
using Twitter, Graphs, GraphPlot, SparseArrays, LinearAlgebra, Colors, Plots 
using Compose, Fontconfig, Cairo;

# %% [markdown]
# ---
# ---
# # Laden der Daten
#
# Zunächst laden wir Daten.
#
# Dazu gibt es in diesen Notebook zwei Optionen.
#
# Für Option 1 wird ein Twitter Account benötigt.
#
# Für Option 2 brauchen wir keinen Twitter Account.
#
#
# ## Option 1: Daten von Twitter laden
#
# Dazu müssen wir uns bei Twitter authentifizieren.
#
# Im Twitter [Developer Portal](https://developer.twitter.com/en) muss eine neue Application erstellt werden.
#
# Dort können dann `CONSUMER_KEY`, `CONSUMER_SECRET`, `ACCESS_TOKEN` und `ACCESS_TOKEN_SECRET` generiert werden.
#
# Siehe auch die [Dokumentation des Twitter.jl Packages](https://github.com/randyzwitch/Twitter.jl)

# %%
CONSUMER_KEY = "";
CONSUMER_SECRET = "";
ACCESS_TOKEN = "";
ACCESS_TOKEN_SECRET = "";

twitterauth(CONSUMER_KEY, CONSUMER_SECRET, ACCESS_TOKEN, ACCESS_TOKEN_SECRET);

# %% [markdown]
# Wir laden die letzten 500 Tweet, die den Hashtag `#DataScience` enthalten.

# %%
tweets = get_search_tweets(q = "#DataScience", count = 500)
T = tweets["statuses"];

# %% [markdown]
# Den letzten dieser Tweets können wir wie folgt anzeigen lassen:

# %%
println(T[1].user["screen_name"])
println(T[1].text)

# %% [markdown]
# Wir wollen die Hashtags in den Tweets analysieren.
#
# Dazu erstellen wir eine Listen von Listen. Die $i$-te Liste enthält die Hashtags im $i$-ten Tweet

# %%
hashtags = Vector{Vector{String}}()
for (i,t) in enumerate(T)
    push!(hashtags, Vector{String}())
    for entry in t.entities["hashtags"]
        push!(hashtags[i], entry["text"])
    end
end
filter!(x -> !isempty(x), hashtags)
hashtags[1:5]
# Out:
# 5-element Vector{Vector{String}}:
#  ["MachineLearning", "AI", "Python"]
#  ["MachineLearning", "Algorithms", "ArtificialIntelligence", "DataScience", "Python", "Programming"]
#  ["machinelearning", "datascience", "bigdata"]
#  ["Python"]
#  ["machinelearning", "datascience", "bigdata"]

# %% [markdown]
# ## Option 2: Daten aus einem .txt File laden
#
#
# Wir können alte Daten aus einem `.txt` File laden (die Daten wurden am 22.04.2022 generiert).

# %%
hashtags = Vector{Vector{String}}()
open("hashtags.txt") do f
    i = 0
    for ln in eachline(f)
        if ln == ""
            push!(hashtags, Vector{String}())
            i+=1
        else
            push!(hashtags[i], ln)
        end
    end
end
hashtags[1:5]
# Out:
# 5-element Vector{Vector{String}}:
#  ["100Daysofcode", "javascript", "programming", "dev", "linux", "java", "programming", "CodeNewbie"]
#  ["100Daysofcode", "javascript", "programming", "dev", "linux", "java", "programming", "CodeNewbie"]
#  ["100Daysofcode", "javascript", "programming", "dev", "linux", "java", "programming", "CodeNewbie"]
#  ["javascript", "programming", "dev", "linux", "java", "programming", "CodeNewbie", "python"]
#  ["javascript", "programming", "dev", "linux", "java", "programming", "CodeNewbie", "python"]

# %% [markdown]
# ---
# # Daten aufbereiten

# %% [markdown]
# Wir erstellen das Array `unique_hashtags`, welches alle Hashtags einzeln listet.

# %%
all_hashtags = vcat(hashtags...)
unique_hashtags = unique(all_hashtags)
# Out:
# 107-element Vector{String}:
#  "MachineLearning"
#  "AI"
#  "Python"
#  "Algorithms"
#  "ArtificialIntelligence"
#  "DataScience"
#  "Programming"
#  "machinelearning"
#  "datascience"
#  "bigdata"
#  "Bioinformatics"
#  "OpenScience"
#  "deeplearning"
#  ⋮
#  "Tech4Good"
#  "womenintech"
#  "Digital"
#  "TechnoCool"
#  "rprogramming"
#  "ai"
#  "ml"
#  "artificialintelligence"
#  "blockchain"
#  "Arduino"
#  "Robotics"
#  "DIY"

# %% [markdown]
# ---
# ---
# # Definition des Graphen
#
# Aus den Daten erstellen wir ein Netzwerk.
#
# Die Knoten im Graphen sind die Hashtags.
#
# Wir definieren eine Kante zwischen zwei Knoten, falls die zwei Hashtags in einem gemeinsamen Tweet auftauchen.
#
# Zuerst berechnen wir die Adjazenzmatrix.

# %%
n = length(unique_hashtags)
A = zeros(Int, n, n)

function edge(hᵢ, hⱼ)
    for h in hashtags
        if hᵢ in h && hⱼ in h
            return 1
        end
    end
    return 0
end
    
    
for i in 2:(n-1)
    hᵢ = unique_hashtags[i]
    for j in (i+1):n
        hⱼ = unique_hashtags[j]
        A[i,j] = edge(hᵢ, hⱼ)
    end
end    
A = sparse(max.(A, A'))
# Out:
# 107×107 SparseMatrixCSC{Int64, Int64} with 764 stored entries:
# ⢰⡲⡖⠂⠐⠒⠒⠒⠀⠀⠀⠂⠂⠀⠂⠀⠀⠐⠒⠒⠒⠀⠒⠀⠒⠒⠐⠂⠀⠐⡀⢐⠀⠀⠀⠀⠀⠀⠀⠀
# ⠸⠉⢫⡲⡐⠚⠋⠩⠄⠠⠤⠍⠉⠤⠅⠠⠀⠀⠀⠈⠉⠌⣿⠤⠛⠛⠉⠁⠀⠈⠈⢹⠀⠀⠀⠀⠀⢰⣶⠉
# ⢰⠀⣰⠈⢠⡶⢀⡀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀
# ⢸⠀⡏⡀⠀⠰⠪⡢⡀⠀⠀⠀⠆⠀⠀⠀⠒⠂⠀⠰⠶⠠⢠⠀⠉⠉⢤⣄⣀⠐⠀⢀⣀⣀⠀⠀⠀⠀⠀⠀
# ⠀⠀⠀⡁⠀⠀⠀⠈⣮⡻⣀⡂⠀⣀⡀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠒⠒⠂⠀⠀⠀
# ⠠⠀⡄⠇⠀⠀⠀⠀⠠⠸⠮⠃⣀⠿⠇⠀⠀⠀⠀⠀⠀⠀⠤⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠤⠤⠄⠀⠀⠀
# ⠈⠀⠃⡄⠀⠀⠈⠁⠀⢠⣤⡜⠚⡠⡄⠀⠀⠀⠀⠈⠉⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀
# ⠈⠀⠁⡁⠀⠀⠀⠀⠀⠈⠉⠁⠀⠉⠠⠂⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀
# ⢀⠀⠀⠀⠀⠀⠸⠀⠀⠀⠀⠀⠀⠀⠀⠀⠮⠃⣀⡀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀
# ⢸⠀⡀⠀⠀⠀⢀⡀⠀⠀⠀⠀⡀⠀⠀⠀⠀⠸⠾⢃⣀⠀⠀⠀⠀⠀⠀⠀⠀⢀⠀⠀⠀⠀⠀⠀⠀⠀⠀⣀
# ⠘⠀⡃⠄⠀⠀⠘⡃⠀⠀⠀⠀⠃⠀⠀⠀⠀⠀⠀⠘⠊⠀⠀⠀⠀⠀⡀⠀⠀⠈⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀
# ⠘⠀⠛⡟⠀⠀⠀⠒⠀⠀⠀⠃⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⢪⡲⠀⠀⠐⠂⠀⠀⠀⠘⠀⠀⠀⠀⠀⠘⠛⠀
# ⢸⠀⣿⠀⠀⠀⡇⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⣯⣻⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀
# ⠰⠀⠇⠀⠀⠀⠀⢷⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠈⠰⠀⠀⠀⠠⡦⣤⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀
# ⢀⠀⡀⠀⠀⠀⢀⠘⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⢀⡀⠀⠀⠀⠀⠀⠀⠛⠚⠀⠀⠈⠉⠉⠀⠀⠀⠀⠀⠀
# ⢀⢈⣆⣀⠀⠀⠀⢀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⣀⠀⠀⠀⠀⠀⡀⠀⠠⠂⣀⣀⠀⠀⠀⢀⣀⠀
# ⠀⠀⠀⠀⠀⠀⠀⢸⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⡇⠀⠀⢸⣮⡿⠀⠀⠀⠀⠀⠀
# ⠀⠀⠀⠀⠀⠀⠀⠀⢸⠀⠀⡇⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⣾⡻⡇⠀⠀⠀
# ⠀⠀⢀⣀⠀⠀⠀⠀⠈⠀⠀⠁⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⣀⠀⠀⠀⠀⠀⠀⠀⠀⢀⠀⠀⠉⠉⠁⢀⣀⠀
# ⠀⠀⡜⠛⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⢠⠀⠀⠛⠀⠀⠀⠀⠀⠀⠀⠀⠘⠀⠀⠀⠀⠀⠘⠊⡤

# %% [markdown]
# die Adjazenzmatrix `A` definiert den Graphen `G`.

# %%
G = Graphs.Graph(A)
# Out:
# {107, 382} undirected simple Int64 graph

# %% [markdown]
# Wir entfernen außerdem die Knoten mit Grad 0 aus dem Graphen.

# %%
d = Graphs.degree(G)
not0 = findall(d .!= 0)

unique_hashtags = unique_hashtags[not0]
A = A[not0,not0]
d = d[not0]

n = length(unique_hashtags)
G = Graphs.Graph(A)
# Out:
# {98, 382} undirected simple Int64 graph

# %% [markdown]
# ---
# ---
# # Visualisierung
#
# Wir visualisieren den Graphen wie folgt.
#
# Dabei plotten wir die Labels der 5 Knoten mit den höchsten Graden.

# %%
c = sortperm(d, rev = true)[1:5]
labels = ["" for _ in 1:n]
labels[c] = unique_hashtags[c] 
layout= spring_layout(G; C=5)
P1 = gplot(G, layout...;
        linetype="curve", 
        nodelabel=labels,
        nodelabeldist=2,
        nodefillc = colorant"steelblue"
)
# Out:
# Context(BBox{l,t,r,b,w,h = 0.0w,0.0h, 1.0w,1.0h, 1.0w,1.0h}, UnitBox{Float64, Float64, Float64, Float64}(-1.2, -1.2, 2.4, 2.4, 0.0mm, 0.0mm, 0.0mm, 0.0mm), nothing, nothing, nothing, List([Context(BBox{l,t,r,b,w,h = 0.0w,0.0h, 1.0w,1.0h, 1.0w,1.0h}, nothing, nothing, nothing, nothing, List([]), List([Compose.Form{Compose.CurvePrimitive{Tuple{Measures.Length{:cx, Float64}, Measures.Length{:cy, Float64}}, Tuple{Measures.Length{:cx, Float64}, Measures.Length{:cy, Float64}}, Tuple{Measures.Length{:cx, Float64}, Measures.Length{:cy, Float64}}, Tuple{Measures.Length{:cx, Float64}, Measures.Length{:cy, Float64}}}}(Compose.CurvePrimitive{Tuple{Measures.Length{:cx, Float64}, Measures.Length{:cy, Float64}}, Tuple{Measures.Length{:cx, Float64}, Measures.Length{:cy, Float64}}, Tuple{Measures.Length{:cx, Float64}, Measures.Length{:cy, Float64}}, Tuple{Measures.Length{:cx, Float64}, Measures.Length{:cy, Float64}}}[Compose.CurvePrimitive{Tuple{Measures.Length{:cx, Float64}, Measures.Length{:cy, Float64}}, Tuple{Measures.Length{:cx, Float64}, Measures.Length{:cy, Float64}}, Tuple{Measures.Length{:cx, Float64}, Measures.Length{:cy, Float64}}, Tuple{Measures.Length{:cx, Float64}, Measures.Length{:cy, Float64}}}((0.37901309109236186cx, 0.2221684076725236cy), (0.4203430890414549cx, 0.2010099931871249cy), (0.428364400763201cx, 0.1851925208615478cy), (0.42101322453614026cx, 0.1393470473435803cy)), Compose.CurvePrimitive{Tuple{Measures.Length{:cx, Float64}, Measures.Length{:cy, Float64}}, Tuple{Measures.Length{:cx, Float64}, Measures.Length{:cy, Float64}}, Tuple{Measures.Length{:cx, Float64}, Measures.Length{:cy, Float64}}, Tuple{Measures.Length{:cx, Float64}, Measures.Length{:cy, Float64}}}((0.37701798730329006cx, 0.24844639595928622cy), (0.47703454515656374cx, 0.32056237769147966cy), (0.5241324079302391cx, 0.3203923253141055cy), (0.6236255983812106cx, 0.24755599015161936cy)), Compose.CurvePrimitive{Tuple{Measures.Length{:cx, Float64}, Measures.Length{:cy, Float64}}, Tuple{Measures.Length{:cx, Float64}, Measures.Length{:cy, Float64}}, Tuple{Measures.Length{:cx, Float64}, Measures.Length{:cy, Float64}}, Tuple{Measures.Length{:cx, Float64}, Measures.Length{:cy, Float64}}}((0.38042998737585654cx, 0.2255078746792179cy), (0.43684695527083695cx, 0.20622258160945617cy), (0.449950939059062cx, 0.18759669984007915cy), (0.4490433372670581cx, 0.12798149159388578cy)), Compose.CurvePrimitive{Tuple{Measures.Length{:cx, Float64}, Measures.Length{:cy, Float64}}, Tuple{Measures.Length{:cx, Float64}, Measures.Length{:cy, Float64}}, Tuple{Measures.Length{:cx, Float64}, Measures.Length{:cy, Float64}}, Tuple{Measures.Length{:cx, Float64}, Measures.Length{:cy, Float64}}}((0.3816854228931083cx, 0.23594558375619223cy), (0.48484221717927456cx, 0.2452522261754889cy), (0.5188088911060836cx, 0.22496799353924543cy), (0.5595372365434504cx, 0.1297359628014018cy)), Compose.CurvePrimitive{Tuple{Measures.Length{:cx, Float64}, Measures.Length{:cy, Float64}}, Tuple{Measures.Length{:cx, Float64}, Measures.Length{:cy, Float64}}, Tuple{Measures.Length{:cx, Float64}, Measures.Length{:cy, Float64}}, Tuple{Measures.Length{:cx, Float64}, Measures.Length{:cy, Float64}}}((0.34895322574847637cx, 0.25776566207467133cy), (0.31928802994461086cx, 0.35203492370303724cy), (0.33128574820107437cx, 0.38782597901670396cy), (0.4117740941142097cx, 0.4451700606834851cy)), Compose.CurvePrimitive{Tuple{Measures.Length{:cx, Float64}, Measures.Length{:cy, Float64}}, Tuple{Measures.Length{:cx, Float64}, Measures.Length{:cy, Float64}}, Tuple{Measures.Length{:cx, Float64}, Measures.Length{:cy, Float64}}, Tuple{Measures.Length{:cx, Float64}, Measures.Length{:cy, Float64}}}((0.33426429836215926cx, 0.24558551843006085cy), (0.17441926543030806cx, 0.33106611330466074cy), (0.14421602306462328cx, 0.39336851566203523cy), (0.17611806819453246cx, 0.5718051323348171cy)), Compose.CurvePrimitive{Tuple{Measures.Length{:cx, Float64}, Measures.Length{:cy, Float64}}, Tuple{Measures.Length{:cx, Float64}, Measures.Length{:cy, Float6 ...

# %% [markdown]
# ---
# ---
# # Die Laplace Matrix
#
# Wir berechnen die Laplace Matrix `L` von `G`.

# %%
L = zeros(n, n)
for i in 1:n
    for j in 1:n
        if i == j
            L[i,j] = 1
        elseif A[i,j] == 1
            L[i,j] = - 1 / sqrt(d[i] * d[j])
        end
    end
end
L;

# %% [markdown]
# Die Eigenwerte von `L` werden dann wie folgt berechnet:

# %%
E = eigen(L)
λ = E.values
P2 = plot(λ, label = "The spectrum of G", 
             legend = 0,
             linewidth = 3,
             xlab = "i",
             ylab = "λᵢ")
# Out:
# ┌ Info: Precompiling GR_jll [d2c73de3-f751-5644-a686-071e5b155ba9]
# └ @ Base loading.jl:1423

# %% [markdown]
# Die Anzahl der Komponenten ist gleich der Dimension des Kerns von `L`.

# %%
n_components = count(λ .< 1e-14)
# Out:
# 3

# %%
C = connected_components(G)
# Out:
# 3-element Vector{Vector{Int64}}:
#  [1, 2, 3, 4, 5, 6, 7, 8, 9, 12  …  89, 90, 91, 92, 93, 94, 95, 96, 97, 98]
#  [10, 11]
#  [38, 39]

# %%
sum(λ), n
# Out:
# (97.99999999999997, 98)

# %% [markdown]
# ---
# # Analyse einer Komponente
#
# Wir analyieren nun die größte Zusammenhangskomponente `H` von `G`
#
# Wir berechnen auch die Zusammenhangskomponenten

# %%
k = findmax(length.(C))
I = C[k[2]];
H = Graph(A[I, I])
# Out:
# {94, 380} undirected simple Int64 graph

# %% [markdown]
# Wir plotten zunächst diese Komponente.

# %%
layout_H = (layout[1][I], layout[2][I])
P3 = gplot(H, layout_H...;
        linetype="curve", 
        nodelabeldist=2,
        nodefillc = colorant"steelblue"
)
# Out:
# Context(BBox{l,t,r,b,w,h = 0.0w,0.0h, 1.0w,1.0h, 1.0w,1.0h}, UnitBox{Float64, Float64, Float64, Float64}(-1.2, -1.2, 2.4, 2.4, 0.0mm, 0.0mm, 0.0mm, 0.0mm), nothing, nothing, nothing, List([Context(BBox{l,t,r,b,w,h = 0.0w,0.0h, 1.0w,1.0h, 1.0w,1.0h}, nothing, nothing, nothing, nothing, List([]), List([Compose.Form{Compose.CurvePrimitive{Tuple{Measures.Length{:cx, Float64}, Measures.Length{:cy, Float64}}, Tuple{Measures.Length{:cx, Float64}, Measures.Length{:cy, Float64}}, Tuple{Measures.Length{:cx, Float64}, Measures.Length{:cy, Float64}}, Tuple{Measures.Length{:cx, Float64}, Measures.Length{:cy, Float64}}}}(Compose.CurvePrimitive{Tuple{Measures.Length{:cx, Float64}, Measures.Length{:cy, Float64}}, Tuple{Measures.Length{:cx, Float64}, Measures.Length{:cy, Float64}}, Tuple{Measures.Length{:cx, Float64}, Measures.Length{:cy, Float64}}, Tuple{Measures.Length{:cx, Float64}, Measures.Length{:cy, Float64}}}[Compose.CurvePrimitive{Tuple{Measures.Length{:cx, Float64}, Measures.Length{:cy, Float64}}, Tuple{Measures.Length{:cx, Float64}, Measures.Length{:cy, Float64}}, Tuple{Measures.Length{:cx, Float64}, Measures.Length{:cy, Float64}}, Tuple{Measures.Length{:cx, Float64}, Measures.Length{:cy, Float64}}}((0.20863341660601997cx, 0.022497320665087833cy), (0.2651847491844422cx, -0.006333548246791755cy), (0.276187138640458cx, -0.02793934192344294cy), (0.26624267571264565cx, -0.09063208373369296cy)), Compose.CurvePrimitive{Tuple{Measures.Length{:cx, Float64}, Measures.Length{:cy, Float64}}, Tuple{Measures.Length{:cx, Float64}, Measures.Length{:cy, Float64}}, Tuple{Measures.Length{:cx, Float64}, Measures.Length{:cy, Float64}}, Tuple{Measures.Length{:cx, Float64}, Measures.Length{:cy, Float64}}}((0.2065763503587972cx, 0.04929028561156392cy), (0.33720272181965094cx, 0.14348015933250016cy), (0.39871543472018867cx, 0.14325898337779952cy), (0.5286610965864411cx, 0.04813219327776287cy)), Compose.CurvePrimitive{Tuple{Measures.Length{:cx, Float64}, Measures.Length{:cy, Float64}}, Tuple{Measures.Length{:cx, Float64}, Measures.Length{:cy, Float64}}, Tuple{Measures.Length{:cx, Float64}, Measures.Length{:cy, Float64}}, Tuple{Measures.Length{:cx, Float64}, Measures.Length{:cy, Float64}}}((0.21007672550868908cx, 0.025916345773529092cy), (0.28598635475167855cx, 0.00013392566863885264cy), (0.3036552062589519cx, -0.0248760539108296cy), (0.3025920330851221cx, -0.10503760742044926cy)), Compose.CurvePrimitive{Tuple{Measures.Length{:cx, Float64}, Measures.Length{:cy, Float64}}, Tuple{Measures.Length{:cx, Float64}, Measures.Length{:cy, Float64}}, Tuple{Measures.Length{:cx, Float64}, Measures.Length{:cy, Float64}}, Tuple{Measures.Length{:cx, Float64}, Measures.Length{:cy, Float64}}}((0.2113379989072834cx, 0.036572980317870984cy), (0.3466700729502326cx, 0.04903230964567379cy), (0.3912872774323136cx, 0.02249851045956701cy), (0.4449567145414678cx, -0.1023597959219128cy)), Compose.CurvePrimitive{Tuple{Measures.Length{:cx, Float64}, Measures.Length{:cy, Float64}}, Tuple{Measures.Length{:cx, Float64}, Measures.Length{:cy, Float64}}, Tuple{Measures.Length{:cx, Float64}, Measures.Length{:cy, Float64}}, Tuple{Measures.Length{:cx, Float64}, Measures.Length{:cy, Float64}}}((0.17795183629624461cx, 0.05881516421559847cy), (0.13923411178362463cx, 0.1823935935349681cy), (0.15501476295877747cx, 0.22927409908065036cy), (0.26058039857855697cx, 0.30428467807234666cy)), Compose.CurvePrimitive{Tuple{Measures.Length{:cx, Float64}, Measures.Length{:cy, Float64}}, Tuple{Measures.Length{:cx, Float64}, Measures.Length{:cy, Float64}}, Tuple{Measures.Length{:cx, Float64}, Measures.Length{:cy, Float64}}, Tuple{Measures.Length{:cx, Float64}, Measures.Length{:cy, Float64}}}((0.16290284000057353cx, 0.04633162692724428cy), (-0.04321691758472343cx, 0.15612518332999348cy), (-0.0822612363185232cx, 0.2363300269721076cy), (-0.04153586702477031cx, 0.46628964036209547cy)), Compose.CurvePrimitive{Tuple{Measures.Length{:cx, Float64}, Measures.Length{:cy, Float64}}, Tuple{Measures.Length{:cx, Float64}, Measu ...

# %% [markdown]
# Jetzt berechnen wir das Spektrum von `H`.

# %%
L_H = L[I,I]
E_H = eigen(L_H)
λ_H = E_H.values
P4 = plot(λ_H, legend = false, linewidth = 3)

# %% [markdown]
# Sei nun `w` Eigenvektor von $\lambda_G$.
#
# Wir plotten die Knoten je nach Vorzeichen von `w` rot oder blau. Wir färben gelb, falls der Eintrag von `w` Null ist.
#
# Dies zeigt uns Komponenten von `H`, die "fast" zusammenhängend sind.

# %%
w = E_H.vectors[:,2]
cols = []
for wᵢ in w
    if abs(wᵢ) > 1e-12 
        if wᵢ < 0
            push!(cols, colorant"steelblue")
        else
            push!(cols, colorant"indianred")
        end
    else
        push!(cols, colorant"orange")
    end
end
layout= x -> spring_layout(x; C=5)
P5 = gplot(H, layout_H...;
        linetype="curve", 
        nodelabeldist=2,
        nodefillc = cols
)
# Out:
# Context(BBox{l,t,r,b,w,h = 0.0w,0.0h, 1.0w,1.0h, 1.0w,1.0h}, UnitBox{Float64, Float64, Float64, Float64}(-1.2, -1.2, 2.4, 2.4, 0.0mm, 0.0mm, 0.0mm, 0.0mm), nothing, nothing, nothing, List([Context(BBox{l,t,r,b,w,h = 0.0w,0.0h, 1.0w,1.0h, 1.0w,1.0h}, nothing, nothing, nothing, nothing, List([]), List([Compose.Form{Compose.CurvePrimitive{Tuple{Measures.Length{:cx, Float64}, Measures.Length{:cy, Float64}}, Tuple{Measures.Length{:cx, Float64}, Measures.Length{:cy, Float64}}, Tuple{Measures.Length{:cx, Float64}, Measures.Length{:cy, Float64}}, Tuple{Measures.Length{:cx, Float64}, Measures.Length{:cy, Float64}}}}(Compose.CurvePrimitive{Tuple{Measures.Length{:cx, Float64}, Measures.Length{:cy, Float64}}, Tuple{Measures.Length{:cx, Float64}, Measures.Length{:cy, Float64}}, Tuple{Measures.Length{:cx, Float64}, Measures.Length{:cy, Float64}}, Tuple{Measures.Length{:cx, Float64}, Measures.Length{:cy, Float64}}}[Compose.CurvePrimitive{Tuple{Measures.Length{:cx, Float64}, Measures.Length{:cy, Float64}}, Tuple{Measures.Length{:cx, Float64}, Measures.Length{:cy, Float64}}, Tuple{Measures.Length{:cx, Float64}, Measures.Length{:cy, Float64}}, Tuple{Measures.Length{:cx, Float64}, Measures.Length{:cy, Float64}}}((0.20863341660601997cx, 0.022497320665087833cy), (0.2651847491844422cx, -0.006333548246791755cy), (0.276187138640458cx, -0.02793934192344294cy), (0.26624267571264565cx, -0.09063208373369296cy)), Compose.CurvePrimitive{Tuple{Measures.Length{:cx, Float64}, Measures.Length{:cy, Float64}}, Tuple{Measures.Length{:cx, Float64}, Measures.Length{:cy, Float64}}, Tuple{Measures.Length{:cx, Float64}, Measures.Length{:cy, Float64}}, Tuple{Measures.Length{:cx, Float64}, Measures.Length{:cy, Float64}}}((0.2065763503587972cx, 0.04929028561156392cy), (0.33720272181965094cx, 0.14348015933250016cy), (0.39871543472018867cx, 0.14325898337779952cy), (0.5286610965864411cx, 0.04813219327776287cy)), Compose.CurvePrimitive{Tuple{Measures.Length{:cx, Float64}, Measures.Length{:cy, Float64}}, Tuple{Measures.Length{:cx, Float64}, Measures.Length{:cy, Float64}}, Tuple{Measures.Length{:cx, Float64}, Measures.Length{:cy, Float64}}, Tuple{Measures.Length{:cx, Float64}, Measures.Length{:cy, Float64}}}((0.21007672550868908cx, 0.025916345773529092cy), (0.28598635475167855cx, 0.00013392566863885264cy), (0.3036552062589519cx, -0.0248760539108296cy), (0.3025920330851221cx, -0.10503760742044926cy)), Compose.CurvePrimitive{Tuple{Measures.Length{:cx, Float64}, Measures.Length{:cy, Float64}}, Tuple{Measures.Length{:cx, Float64}, Measures.Length{:cy, Float64}}, Tuple{Measures.Length{:cx, Float64}, Measures.Length{:cy, Float64}}, Tuple{Measures.Length{:cx, Float64}, Measures.Length{:cy, Float64}}}((0.2113379989072834cx, 0.036572980317870984cy), (0.3466700729502326cx, 0.04903230964567379cy), (0.3912872774323136cx, 0.02249851045956701cy), (0.4449567145414678cx, -0.1023597959219128cy)), Compose.CurvePrimitive{Tuple{Measures.Length{:cx, Float64}, Measures.Length{:cy, Float64}}, Tuple{Measures.Length{:cx, Float64}, Measures.Length{:cy, Float64}}, Tuple{Measures.Length{:cx, Float64}, Measures.Length{:cy, Float64}}, Tuple{Measures.Length{:cx, Float64}, Measures.Length{:cy, Float64}}}((0.17795183629624461cx, 0.05881516421559847cy), (0.13923411178362463cx, 0.1823935935349681cy), (0.15501476295877747cx, 0.22927409908065036cy), (0.26058039857855697cx, 0.30428467807234666cy)), Compose.CurvePrimitive{Tuple{Measures.Length{:cx, Float64}, Measures.Length{:cy, Float64}}, Tuple{Measures.Length{:cx, Float64}, Measures.Length{:cy, Float64}}, Tuple{Measures.Length{:cx, Float64}, Measures.Length{:cy, Float64}}, Tuple{Measures.Length{:cx, Float64}, Measures.Length{:cy, Float64}}}((0.16290284000057353cx, 0.04633162692724428cy), (-0.04321691758472343cx, 0.15612518332999348cy), (-0.0822612363185232cx, 0.2363300269721076cy), (-0.04153586702477031cx, 0.46628964036209547cy)), Compose.CurvePrimitive{Tuple{Measures.Length{:cx, Float64}, Measures.Length{:cy, Float64}}, Tuple{Measures.Length{:cx, Float64}, Measu ...

# %% [markdown]
# Die Labels der zwei Cluster sind wie folgt:

# %%
unique_hashtags[I][w .> 0]
# Out:
# 69-element Vector{String}:
#  "AI"
#  "Python"
#  "Algorithms"
#  "ArtificialIntelligence"
#  "DataScience"
#  "Programming"
#  "machinelearning"
#  "bigdata"
#  "deeplearning"
#  "proteins"
#  "IA"
#  "ML"
#  "5G"
#  ⋮
#  "Infographic"
#  "cprogramming"
#  "cprogram"
#  "cloud"
#  "cloudcomputing"
#  "ai"
#  "ml"
#  "artificialintelligence"
#  "blockchain"
#  "Arduino"
#  "Robotics"
#  "DIY"

# %%
unique_hashtags[I][w .< 0]
# Out:
# 25-element Vector{String}:
#  "datascience"
#  "Scientists"
#  "Risk"
#  "Disorder"
#  "Kids"
#  "OTTalk"
#  "OccupationalTherapy"
#  "healthcare"
#  "innovation"
#  "science"
#  "philosophy"
#  "bayes"
#  "Bangalore"
#  "digitaltransformation"
#  "tech"
#  "analytics"
#  "ds"
#  "statistics"
#  "Assessment"
#  "economy"
#  "marketing"
#  "investing"
#  "Tech4Good"
#  "womenintech"
#  "Digital"

# %% [markdown]
# Jetzt färben wir ähnlich für den größten Eigenwert.

# %%
u = E_H.vectors[:,end]
cols = []
for uᵢ in u
    if abs(uᵢ) > 1e-12 
        if uᵢ < 0
            push!(cols, colorant"steelblue")
        else
            push!(cols, colorant"indianred")
        end
    else
        push!(cols, colorant"orange")
    end
end
P6 = gplot(H, layout_H...;
        linetype="curve", 
        nodelabeldist=2,
        nodefillc = cols
)
# Out:
# Context(BBox{l,t,r,b,w,h = 0.0w,0.0h, 1.0w,1.0h, 1.0w,1.0h}, UnitBox{Float64, Float64, Float64, Float64}(-1.2, -1.2, 2.4, 2.4, 0.0mm, 0.0mm, 0.0mm, 0.0mm), nothing, nothing, nothing, List([Context(BBox{l,t,r,b,w,h = 0.0w,0.0h, 1.0w,1.0h, 1.0w,1.0h}, nothing, nothing, nothing, nothing, List([]), List([Compose.Form{Compose.CurvePrimitive{Tuple{Measures.Length{:cx, Float64}, Measures.Length{:cy, Float64}}, Tuple{Measures.Length{:cx, Float64}, Measures.Length{:cy, Float64}}, Tuple{Measures.Length{:cx, Float64}, Measures.Length{:cy, Float64}}, Tuple{Measures.Length{:cx, Float64}, Measures.Length{:cy, Float64}}}}(Compose.CurvePrimitive{Tuple{Measures.Length{:cx, Float64}, Measures.Length{:cy, Float64}}, Tuple{Measures.Length{:cx, Float64}, Measures.Length{:cy, Float64}}, Tuple{Measures.Length{:cx, Float64}, Measures.Length{:cy, Float64}}, Tuple{Measures.Length{:cx, Float64}, Measures.Length{:cy, Float64}}}[Compose.CurvePrimitive{Tuple{Measures.Length{:cx, Float64}, Measures.Length{:cy, Float64}}, Tuple{Measures.Length{:cx, Float64}, Measures.Length{:cy, Float64}}, Tuple{Measures.Length{:cx, Float64}, Measures.Length{:cy, Float64}}, Tuple{Measures.Length{:cx, Float64}, Measures.Length{:cy, Float64}}}((0.20863341660601997cx, 0.022497320665087833cy), (0.2651847491844422cx, -0.006333548246791755cy), (0.276187138640458cx, -0.02793934192344294cy), (0.26624267571264565cx, -0.09063208373369296cy)), Compose.CurvePrimitive{Tuple{Measures.Length{:cx, Float64}, Measures.Length{:cy, Float64}}, Tuple{Measures.Length{:cx, Float64}, Measures.Length{:cy, Float64}}, Tuple{Measures.Length{:cx, Float64}, Measures.Length{:cy, Float64}}, Tuple{Measures.Length{:cx, Float64}, Measures.Length{:cy, Float64}}}((0.2065763503587972cx, 0.04929028561156392cy), (0.33720272181965094cx, 0.14348015933250016cy), (0.39871543472018867cx, 0.14325898337779952cy), (0.5286610965864411cx, 0.04813219327776287cy)), Compose.CurvePrimitive{Tuple{Measures.Length{:cx, Float64}, Measures.Length{:cy, Float64}}, Tuple{Measures.Length{:cx, Float64}, Measures.Length{:cy, Float64}}, Tuple{Measures.Length{:cx, Float64}, Measures.Length{:cy, Float64}}, Tuple{Measures.Length{:cx, Float64}, Measures.Length{:cy, Float64}}}((0.21007672550868908cx, 0.025916345773529092cy), (0.28598635475167855cx, 0.00013392566863885264cy), (0.3036552062589519cx, -0.0248760539108296cy), (0.3025920330851221cx, -0.10503760742044926cy)), Compose.CurvePrimitive{Tuple{Measures.Length{:cx, Float64}, Measures.Length{:cy, Float64}}, Tuple{Measures.Length{:cx, Float64}, Measures.Length{:cy, Float64}}, Tuple{Measures.Length{:cx, Float64}, Measures.Length{:cy, Float64}}, Tuple{Measures.Length{:cx, Float64}, Measures.Length{:cy, Float64}}}((0.2113379989072834cx, 0.036572980317870984cy), (0.3466700729502326cx, 0.04903230964567379cy), (0.3912872774323136cx, 0.02249851045956701cy), (0.4449567145414678cx, -0.1023597959219128cy)), Compose.CurvePrimitive{Tuple{Measures.Length{:cx, Float64}, Measures.Length{:cy, Float64}}, Tuple{Measures.Length{:cx, Float64}, Measures.Length{:cy, Float64}}, Tuple{Measures.Length{:cx, Float64}, Measures.Length{:cy, Float64}}, Tuple{Measures.Length{:cx, Float64}, Measures.Length{:cy, Float64}}}((0.17795183629624461cx, 0.05881516421559847cy), (0.13923411178362463cx, 0.1823935935349681cy), (0.15501476295877747cx, 0.22927409908065036cy), (0.26058039857855697cx, 0.30428467807234666cy)), Compose.CurvePrimitive{Tuple{Measures.Length{:cx, Float64}, Measures.Length{:cy, Float64}}, Tuple{Measures.Length{:cx, Float64}, Measures.Length{:cy, Float64}}, Tuple{Measures.Length{:cx, Float64}, Measures.Length{:cy, Float64}}, Tuple{Measures.Length{:cx, Float64}, Measures.Length{:cy, Float64}}}((0.16290284000057353cx, 0.04633162692724428cy), (-0.04321691758472343cx, 0.15612518332999348cy), (-0.0822612363185232cx, 0.2363300269721076cy), (-0.04153586702477031cx, 0.46628964036209547cy)), Compose.CurvePrimitive{Tuple{Measures.Length{:cx, Float64}, Measures.Length{:cy, Float64}}, Tuple{Measures.Length{:cx, Float64}, Measu ...

# %%
unique_hashtags[I][u .> 1e-12], unique_hashtags[I][u .< -1e-12]
# Out:
# (["NumPy"], ["CheatSheet"])

# %% [markdown]
# Die Plots können schließlich wie folgt gespeichert werden:

# %%
draw(PDF("plot.pdf", 16cm, 16cm), P1)
